# %%
import pandas as pd
import requests

# %%
url_base = "https://www.bibsonomy.org/json/search/"
url_attr = "?items=1000"
def df_from_query(query):
    url = url_base + query.replace(" ", "%20") + url_attr
    result = requests.get(url)
    json_data = result.json()
    dataframe = pd.DataFrame(json_data["items"])
    return dataframe

# %%
df = df_from_query("desk lamp")

# %%
dataframes = []

# %%
queries = ["social change", "religious studies", "gender studies"]
for q in queries:
    df = df_from_query(q)
    dataframes.append(df)
    print(f'Ergebnisse für {q} gefunden. Dataframe enthält {len(df["id"])} Einträge.')
# Out:
# Ergebnisse für social change gefunden. Dataframe enthält 1827 Einträge.
# Ergebnisse für religious studies gefunden. Dataframe enthält 395 Einträge.
# Ergebnisse für gender studies gefunden. Dataframe enthält 1336 Einträge.

# %%
# über "ignore_index" können wir den Index "resetten" und so die Einträge neu fortlaufend nummerieren
data = pd.concat(dataframes, ignore_index=True)

# %%
data
# Out:
#              type                                                 id  \
# 0        Bookmark  https://www.bibsonomy.org/url/d419c0a96cb72afe...
# 1        Bookmark  https://www.bibsonomy.org/url/b05afd3a9118598d...
# 2        Bookmark  https://www.bibsonomy.org/url/d40eed70d5bd15b4...
# 3        Bookmark  https://www.bibsonomy.org/url/48055fef30f0ca3c...
# 4        Bookmark  https://www.bibsonomy.org/url/9707f1cf0c3fb175...
# ...           ...                                                ...
# 3553  Publication  https://www.bibsonomy.org/bibtex/2212a346d1434...
# 3554  Publication  https://www.bibsonomy.org/bibtex/2b744c175b3fb...
# 3555  Publication  https://www.bibsonomy.org/bibtex/287ece6dd0365...
# 3556  Publication  https://www.bibsonomy.org/bibtex/2b2a737d58e88...
# 3557  Publication  https://www.bibsonomy.org/bibtex/26b5dbe6e49b9...
#
#                                                    tags  \
# 0                                             [library]
# 1                                          [socialcare]
# 2     [2014_E852, identity, social_change, sociocult...
# 3     [Lesezeichen-Symbolleiste, ~Allgemein, ~LIS, R...
# 4     [Lesezeichen-Symbolleiste, ~Allgemein, Datenba...
# ...                                                 ...
# 3553  [Theoretical, {Phosphorus, complexes;, crystal...
# 3554  [35q55-nls-like-equations, 35k57-reaction-diff...
# 3555                                         [imported]
# 3556  [Congresses, USA, Corporations, Konzentration_...
# 3557                                [gedispub, itegpub]
#
#                              intraHash  \
# 0     d419c0a96cb72afe31ba77d9c2e9f50f
# 1     b05afd3a9118598ddd6b69113e5168c8
# 2     d40eed70d5bd15b4bc1ec197cb99b113
# 3     48055fef30f0ca3ce9041ce707a0b940
# 4     9707f1cf0c3fb17555d179b1f5ac6b1e
# ...                                ...
# 3553  212a346d143403c373d58953f247c2f2
# 3554  b744c175b3fbf94920066a3d9c67d1ad
# 3555  87ece6dd0365e564fd876ee248a0cef4
# 3556  b2a737d58e883189b6ef350a6c25b52b
# 3557  6b5dbe6e49b95975f835b0ba2a896d87
#
#                                                   label          user  \
# 0     Information for Social Change Journal and Blog...    mikaelbook
# 1     How Social Workers Assess Parental Capacity to...  sssftlibrary
# 2         Identity, language learning and social change  anamcdermott
# 3           Information for Social Change Journal (ISC)        dumuzo
# 4           Information for Social Change Journal (ISC)        dumuzo
# ...                                                 ...           ...
# 3553  Structural, theoretical and multinuclear NMR s...      hkhavasi
# 3554  Integral Manifolds and Inertial Manifolds for ...      gdmcbain
# 3555         Economic relations after the Kennedy Round  fbw_hannover
# 3556               The impact of the modern corporation  fbw_hannover
# 3557  Hybrid Spaces, Hybrid Methodologies: Finding W...       limabla
#
#                                             description                 date  \
# 0     The Journal of Information for Social Change b...  2020-04-09 08:26:12
# 1     Dendy Platt examines the potential for the C-C...  2016-05-11 13:39:47
# 2     An article on identity, language learning and ...  2014-11-15 16:19:15
# 3     Information for Social Change is an activist o...  2014-08-16 11:31:22
# 4     Information for Social Change is an activist o...  2014-08-16 11:31:14
# ...                                                 ...                  ...
# 3553                                                     2017-05-10 15:29:29
# 3554                                                     2017-06-29 07:13:07
# 3555                                                     2009-08-21 12:35:36
# 3556                                                     2009-08-21 10:31:17
# 3557                                                     2022-06-27 12:17:41
#
#                changeDate  count  ... adsnote adsurl researcherid-numbers  \
# 0     2020-04-09 08:26:12      1  ...     NaN    NaN                  NaN
# 1     2016-05-11 13:39:47      1  ...     NaN    NaN                  NaN
# 2     2014-11-17 09:54:33      1  ...     NaN    NaN                  NaN
# 3     2014-08-16 11:36:07      1  ...     NaN    NaN                  NaN
# 4     2014-08-16 11:35:51      1  ...     NaN    NaN                  NaN
# ...                   ...    ...  ...     ...    ...                  ...
# 3553  2017-05-10 15:29:29      1  ...     NaN    NaN                  NaN
# 3554  2021-03-18 02:16:50      1  ...     NaN    NaN                  NaN
# 3555  2009-08-21 12:35:46      1  ...     NaN    NaN                  NaN
# 3556  2009-08-21 10:32:22      1  ...     NaN    NaN                  NaN
# 3557  2022-06-27 12:17:41      2  ...     NaN    NaN                  NaN
#
#      pubmedid article-number opturl collection journaltitle days adress
# 0         NaN            NaN    NaN        NaN          NaN  NaN    NaN
# 1         NaN            NaN    NaN        NaN          NaN  NaN    NaN
# 2         NaN            NaN    NaN        NaN          NaN  NaN    NaN
# 3         NaN            NaN    NaN        NaN          NaN  NaN    NaN
# 4         NaN            NaN    NaN        NaN          NaN  NaN    NaN
# ...       ...            ...    ...        ...          ...  ...    ...
# 3553      NaN            NaN    NaN        NaN          NaN  NaN    NaN
# 3554      NaN            NaN    NaN        NaN          NaN  NaN    NaN
# 3555      NaN            NaN    NaN        NaN          NaN  NaN    NaN
# 3556      NaN            NaN    NaN        NaN          NaN  NaN    NaN
# 3557      NaN            NaN    NaN        NaN          NaN  NaN    NaN
#
# [3558 rows x 208 columns]

# %%
data.to_json("test.json")
