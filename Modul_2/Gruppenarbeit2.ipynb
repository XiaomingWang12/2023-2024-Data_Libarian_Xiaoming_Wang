# %%
# %pip install python-terrier
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyterrier as pt

# %%
import json

# %%
import pandas as pd
import pickle
import nltk
import numpy as np

# %%
! ls
# Out:
# bibsonomy.json					   pl_publications.pkl
# Gruppenarbeit1.ipynb				   PyTerrier.ipynb
# Gruppenarbeit2.ipynb				   QnA_Session.ipynb
# Hausaufgaben_Modul2.ipynb			   rl_index
# literature.json					   rl_index_mult
# orientalism_and_social_anthropology.json	   rl_publications.pkl
# orientalism_and_social_anthropology_selected.json  semantic_scholar.json
# orientalism.json				   social_anthropology.json
# pl_index					   test.json
# pl_index_mult					   web_interface.py

# %%
df_li = pd.read_json("literature.json")

# %%
df_li
# Out:
#                         query  \
# 0     artificial intelligence
# 1     artificial intelligence
# 2     artificial intelligence
# 3     artificial intelligence
# 4     artificial intelligence
# ...                       ...
# 4737     large language model
# 4738     large language model
# 4739     large language model
# 4740     large language model
# 4741     large language model
#
#                                                   title  \
# 0                Artificial Intelligence in Agriculture
# 1             Artificial Intelligence Benefit and Risks
# 2              Artificial Intelligence in Power Station
# 3     Artificial Intelligence Based Training and Pla...
# 4     The Significance of Artificial Intelligence in...
# ...                                                 ...
# 4737  Phonologically Aware Neural Model for Named En...
# 4738          Large-Scale Distributed Language Modeling
# 4739  BERT for Joint Intent Classification and Slot ...
# ...
