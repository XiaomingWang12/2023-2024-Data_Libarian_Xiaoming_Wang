# %%
import urllib.request
import pandas as pd

# %%
url = "https://data.seattle.gov/resource/tmmm-ytt6.csv?$where=checkoutyear=2018&$limit=10000"
checkout_file = "checkout.csv"
urllib.request.urlretrieve(url, checkout_file)
# Out:
# ('checkout.csv', <http.client.HTTPMessage at 0x7f4a33f73bd0>)

# %%
checkouts_df = pd.read_csv(checkout_file)

# %%
checkouts_df
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 0       Digital    OverDrive        EBOOK          2018              1
# 1       Digital       Hoopla   TELEVISION          2018              1
# 2      Physical      Horizon    SOUNDDISC          2018              1
# 3       Digital    OverDrive        EBOOK          2018              1
# 4       Digital    OverDrive        EBOOK          2018              1
# ...         ...          ...          ...           ...            ...
# 9995    Digital    OverDrive        EBOOK          2018              1
# 9996    Digital    OverDrive        EBOOK          2018              1
# 9997    Digital      Freegal         SONG          2018              1
# 9998   Physical      Horizon         BOOK          2018              1
# 9999   Physical      Horizon    SOUNDDISC          2018              1
#
#       checkouts                                              title  isbn  \
# ...

# %%
checkouts_df.shape
# Out:
# (10000, 12)

# %%
checkouts_df["checkoutmonth"].unique()
# Out:
# array([ 1,  2,  3,  4,  5,  8,  9, 10, 11, 12])

# %%
checkouts_df["usageclass"].unique()
# Out:
# array(['Digital', 'Physical'], dtype=object)

# %%
checkouts_df["materialtype"].unique()
# Out:
# array(['EBOOK', 'TELEVISION', 'SOUNDDISC', 'BOOK', 'AUDIOBOOK', 'COMIC',
#        'MOVIE', 'SONG', 'MUSIC', 'MAGAZINE', 'VIDEODISC', 'SOUNDREC',
#        'SOUNDDISC, VIDEODISC', 'CR', 'LARGEPRINT', 'ER, SOUNDDISC',
#        'ATLAS', 'ER', 'MAP', 'VIDEOCASS, VIDEODISC', 'REGPRINT', 'VIDEO',
#        'SOUNDCASS', 'ER, VIDEODISC'], dtype=object)

# %%
checkouts_df[checkouts_df["materialtype"] == "EBOOK"]
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 0       Digital    OverDrive        EBOOK          2018              1
# 3       Digital    OverDrive        EBOOK          2018              1
# 4       Digital    OverDrive        EBOOK          2018              1
# 5       Digital    OverDrive        EBOOK          2018              1
# 6       Digital    OverDrive        EBOOK          2018              1
# ...         ...          ...          ...           ...            ...
# 9988    Digital    OverDrive        EBOOK          2018              1
# 9989    Digital    OverDrive        EBOOK          2018              1
# 9992    Digital    OverDrive        EBOOK          2018              1
# 9995    Digital    OverDrive        EBOOK          2018              1
# 9996    Digital    OverDrive        EBOOK          2018              1
#
#       checkouts                                              title  isbn  \
# ...

# %%
checkouts_df["subjects"].unique()
# Out:
# array(['Fiction, Literature, Thriller', "Children's",
#        'Country music 2011 2020', ...,
#        'Chicano movement History, Chicano movement Colorado History, Chicano movement New Mexico History, Civil rights movements United States, Documentary films, Feature films, Nonfiction films',
#        'Boarding schools Fiction, Schools Fiction, Etiquette Fiction, Werewolves Fiction, Great Britain History Victoria 1837 1901 Fiction, Young adult fiction, Spy stories, Science fiction',
#        'Space race United States History 20th century, Space race Soviet Union History 20th century, Cold War, Sputnik satellites, United States Politics and government 1953 1961, Soviet Union Politics and government 1953 1985'],
#       dtype=object)

# %%
checkouts_df[checkouts_df["creator"] == "Dee Brown"]
# Out:
# Empty DataFrame
# Columns: [usageclass, checkouttype, materialtype, checkoutyear, checkoutmonth, checkouts, title, isbn, creator, subjects, publisher, publicationyear]
# Index: []

# %%
checkouts_df["publisher"].unique()
# Out:
# array(['Simon & Schuster, Inc.', 'DHX Media', 'Valory,', ...,
#        'Zhong xin chu ban she,', 'Gibbs Smith', 'HighBridge,'],
#       dtype=object)

# %%
checkouts_df[checkouts_df["publisher"] == "Zhong xin chu ban she"]
# Out:
# Empty DataFrame
# Columns: [usageclass, checkouttype, materialtype, checkoutyear, checkoutmonth, checkouts, title, isbn, creator, subjects, publisher, publicationyear]
# Index: []

# %%
checkouts_df["materialtype"].unique()
# Out:
# array(['EBOOK', 'TELEVISION', 'SOUNDDISC', 'BOOK', 'AUDIOBOOK', 'COMIC',
#        'MOVIE', 'SONG', 'MUSIC', 'MAGAZINE', 'VIDEODISC', 'SOUNDREC',
#        'SOUNDDISC, VIDEODISC', 'CR', 'LARGEPRINT', 'ER, SOUNDDISC',
#        'ATLAS', 'ER', 'MAP', 'VIDEOCASS, VIDEODISC', 'REGPRINT', 'VIDEO',
#        'SOUNDCASS', 'ER, VIDEODISC'], dtype=object)

# %%
checkouts_df[checkouts_df["subjects"] == "Fiction"]
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 172     Digital    OverDrive        EBOOK          2018              1
# 185     Digital    OverDrive        EBOOK          2018              1
# 685     Digital    OverDrive    AUDIOBOOK          2018              1
# 1767    Digital    OverDrive        EBOOK          2018              1
# 3183    Digital    OverDrive        EBOOK          2018              1
# 5805    Digital    OverDrive    AUDIOBOOK          2018              1
# 5924    Digital    OverDrive        EBOOK          2018              1
# 6824    Digital    OverDrive        EBOOK          2018              1
# 7433    Digital    OverDrive        EBOOK          2018              1
# 8512    Digital    OverDrive        EBOOK          2018              1
#
#       checkouts                                              title  isbn  \
# 172           3                               Warrior of the Light   NaN
# ...

# %%
checkouts_df[checkouts_df["publicationyear"] == "2013"]
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 8       Digital    OverDrive        EBOOK          2018              2
# 37      Digital    OverDrive        EBOOK          2018              3
# 50      Digital    OverDrive        EBOOK          2018             12
# 51      Digital    OverDrive        EBOOK          2018             12
# 56      Digital    OverDrive        EBOOK          2018             12
# ...         ...          ...          ...           ...            ...
# 9839    Digital    OverDrive        EBOOK          2018              1
# 9861    Digital    OverDrive        EBOOK          2018              1
# 9885    Digital    OverDrive        EBOOK          2018              1
# 9902    Digital    OverDrive        EBOOK          2018              1
# 9928    Digital    OverDrive        EBOOK          2018              1
#
#       checkouts                                          title  isbn  \
# ...

# %%
checkouts_2013_df = checkouts_df[checkouts_df["publicationyear"] == "2013"]

# %%
checkouts_2013_df.shape
# Out:
# (416, 12)

# %%
checkouts_2013_df.to_csv("checkout_2013_only.csv")

# %%
checkouts_2013_df.to_excel("checkout_2013_only.xlsx")

# %%
checkouts_df["publicationyear"].value_counts()
# Out:
# publicationyear
# 2017             473
# [2017]           417
# 2013             416
# 2014             343
# [2016]           324
#                 ...
# 1961.              1
# [1941]             1
# 2016, [c2015]      1
# [1965-71]          1
# 1958.              1
# Name: count, Length: 263, dtype: int64

# %%
# %matplotlib inline

# %%
checkouts_df["publicationyear"].value_counts().plot(kind="line")
# Out:
# <Axes: xlabel='publicationyear'>

# %%
checkouts_df["checkouts"].hist()
# Out:
# <Axes: >

# %%
checkouts_df["publicationyear"].hist()
# Out:
# <Axes: >

# %%
checkout_file = "checkout_2013_only.csv"

# %%
checkouts_df = pd.read_csv(checkout_file)

# %%
checkouts_df
# Out:
#      Unnamed: 0 usageclass checkouttype materialtype  checkoutyear  \
# 0             8    Digital    OverDrive        EBOOK          2018
# 1            37    Digital    OverDrive        EBOOK          2018
# 2            50    Digital    OverDrive        EBOOK          2018
# 3            51    Digital    OverDrive        EBOOK          2018
# 4            56    Digital    OverDrive        EBOOK          2018
# ..          ...        ...          ...          ...           ...
# 411        9839    Digital    OverDrive        EBOOK          2018
# 412        9861    Digital    OverDrive        EBOOK          2018
# 413        9885    Digital    OverDrive        EBOOK          2018
# 414        9902    Digital    OverDrive        EBOOK          2018
# 415        9928    Digital    OverDrive        EBOOK          2018
#
#      checkoutmonth  checkouts                                          title  \
# 0                2          1                                    Krik? Krak!
# ...

# %%
# %matplotlib inline

# %%
checkouts_df["che"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='materialtype'>

# %%
checkouts_df[checkouts_df["publisher"] == "Penguin Group (USA), Inc."].value_counts().plot(kind="bar")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 checkouts_df[checkouts_df["publisher"] == "Penguin Group (USA), Inc."].value_counts().plot(kind="bar")
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/plotting/_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     972             label_name = label_kw or data.columns
#     973             data.columns = label_name
# --> 975 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...
