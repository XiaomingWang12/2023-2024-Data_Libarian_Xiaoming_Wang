# %%
import pandas as pd

# %%
df = pd.read_csv("data/Library_Usage.csv")
# Out:
# /tmp/ipykernel_3694/1525811659.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("data/Library_Usage.csv")

# %%
df['Circulation Active Year'] = pd.to_numeric(
    df['Circulation Active Year'], errors='coerce')

# %%
df['Circulation Active Year']
# Out:
# 0         2023.0
# 1         2023.0
# 2         2023.0
# 3         2023.0
# 4         2023.0
#            ...
# 436285    2022.0
# 436286    2015.0
# 436287    2022.0
# 436288    2020.0
# 436289    2023.0
# Name: Circulation Active Year, Length: 436290, dtype: float64

# %%
df['Circulation Active Month'] = pd.to_datetime(
    df['Circulation Active Month'], errors='coerce', format="%B")

# %%
df['Circulation Active Month']
# Out:
# 0        NaT
# 1        NaT
# 2        NaT
# 3        NaT
# 4        NaT
#           ..
# 436285   NaT
# 436286   NaT
# 436287   NaT
# 436288   NaT
# 436289   NaT
# Name: Circulation Active Month, Length: 436290, dtype: datetime64[ns]

# %%
df['Circulation Active Month'] = df['Circulation Active Month'].dt.month

# %%
df['Membership Duration'] = (df['Circulation Active Year'] - df['Year Patron Registered'])*12 + df['Circulation Active Month']

# %%
df.to_csv("data/Library_Usage_Membership_Duration.csv")

# %%
df.head(10)
# Out:
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 5                  Staff               53              15
# 1                 5                  Staff              480             378
# 2                 5                  Staff               70              33
# 3                 5                  Staff             3934            2140
# 4                 5                  Staff             1118            1035
# 5                 5                  Staff             2635            4075
# 6                 5                  Staff              774             218
# 7                 5                  Staff              508             330
# 8                 5                  Staff              178              27
# 9                 5                  Staff              110              41
#
#         Age Range Home Library Code Home Library Definition  \
# 0             NaN                b2                 Bayview
# ...

# %%
row_filter = df['Membership Duration'] >=5
df.loc[row_filter]
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 38                    10                Visitor                8
# 42                    10                Visitor                9
# 49                    10                Visitor                2
# 56                     0                  Adult                5
# 113                    4                Welcome                0
# ...                  ...                    ...              ...
# 436153                 0                  Adult                0
# 436199                 0                  Adult               13
# 436250                16    Digital Access Card                0
# 436255                16    Digital Access Card                0
# 436267                 0                  Adult                0
#
#         Total Renewals       Age Range Home Library Code  \
# 38                   5  25 to 34 years                n4
# 42                   5  45 to 54 years                r3
# ...

# %%
df[df['Membership Duration'].isna()]
df.isna().sum()
# Out:
# Patron Type Code                     0
# Patron Type Definition               0
# Total Checkouts                      0
# Total Renewals                       0
# Age Range                          912
# Home Library Code                    2
# Home Library Definition             30
# Circulation Active Month        403786
# Circulation Active Year          39513
# Notice Preference Code           42989
# Notice Preference Definition     42989
# Provided Email Address               0
# Year Patron Registered               0
# Within San Francisco County       1207
# Membership Duration             403786
# dtype: int64

# %%
row_filter = df['Membership Duration'] == 'NaN'
df.loc[row_filter]
# Out:
# Empty DataFrame
# Columns: [Patron Type Code, Patron Type Definition, Total Checkouts, Total Renewals, Age Range, Home Library Code, Home Library Definition, Circulation Active Month, Circulation Active Year, Notice Preference Code, Notice Preference Definition, Provided Email Address, Year Patron Registered, Within San Francisco County, Membership Duration]
# Index: []

# %%
df["Year Patron Registered"].value_counts(normalize=True)
# Out:
# Year Patron Registered
# 2022    0.119583
# 2019    0.101515
# 2003    0.094052
# 2021    0.074799
# 2020    0.073369
# 2017    0.067203
# 2018    0.065603
# 2023    0.060249
# 2016    0.049781
# 2015    0.046201
# 2014    0.036593
# 2013    0.030553
# 2012    0.029066
# 2011    0.028348
# 2009    0.026109
# 2010    0.025779
# 2008    0.023154
# 2007    0.014862
# 2006    0.012042
# 2005    0.010910
# 2004    0.010229
# Name: proportion, dtype: float64

# %%
df[df["Circulation Active Year"].isna()]
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 45                     1               Juvenile                0
# 64                     2                   Teen                0
# 65                     3                 Senior                0
# 72                    10                Visitor                0
# 86                     1               Juvenile                0
# ...                  ...                    ...              ...
# 436262                 2                   Teen                0
# 436268                 2                   Teen                0
# 436273                 0                  Adult                0
# 436275                 2                   Teen                0
# 436280                 0                  Adult                0
#
#         Total Renewals          Age Range Home Library Code  \
# 45                   0       0 to 9 years                 x
# 64                   0     10 to 19 years                 x
# ...

# %%
df["Year Patron Registered"].dtypes
# Out:
# dtype('int64')

# %%
df.head(100)
# Out:
#     Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                  5                  Staff               53              15
# 1                  5                  Staff              480             378
# 2                  5                  Staff               70              33
# 3                  5                  Staff             3934            2140
# 4                  5                  Staff             1118            1035
# ..               ...                    ...              ...             ...
# 95                10                Visitor               11               0
# 96                 1               Juvenile                0               0
# 97                10                Visitor                0               0
# 98                 0                  Adult              111             113
# 99                16    Digital Access Card                0               0
#
# ...

# %%
df.describe(include='all')
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# count      436290.000000                 436290    436290.000000
# unique               NaN                     17              NaN
# top                  NaN                  Adult              NaN
# freq                 NaN                 274682              NaN
# mean            1.081295                    NaN       160.294843
# min             0.000000                    NaN         0.000000
# 25%             0.000000                    NaN         0.000000
# 50%             0.000000                    NaN         7.000000
# 75%             1.000000                    NaN        78.000000
# max           104.000000                    NaN     45380.000000
# std             3.383103                    NaN       537.923680
#
#         Total Renewals       Age Range Home Library Code  \
# count    436290.000000          435378            436288
# unique             NaN              10                75
# ...

# %%
print(df["Total Renewals"].min())
# Out:
# 0

# %%
print(df.min())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 print(df.min())
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:11669, in NDFrame._add_numeric_operations.<locals>.min(self, axis, skipna, numeric_only, **kwargs)
#   11650 @doc(
#   11651     _num_doc,
#   11652     desc="Return the minimum of the values over the requested axis.\n\n"
#    (...)
#   11667     **kwargs,
#   11668 ):
# > 11669     return NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:11169, in NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#   11162 def min(
#   11163     self,
#   11164     axis: Axis | None = 0,
#    (...)
#   11167     **kwargs,
#   11168 ):
# > 11169     return self._stat_function(
#   11170         "min",
#   11171         nanops.nanmin,
# ...

# %%
df['Total Renewals'].sum()
# Out:
# 34169162

# %%
df['Total Renewals'].between(100, 200).sum()
# Out:
# 24595

# %%
df['membership duration'] = ('Circulation Active Year' - 'Year Patron Registered')*12 + 'Circulation Active Month'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df['membership duration'] = ('Circulation Active Year' - 'Year Patron Registered')*12 + 'Circulation Active Month'
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
df[:10]
# Out:
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 5                  Staff               53              15
# 1                 5                  Staff              480             378
# 2                 5                  Staff               70              33
# 3                 5                  Staff             3934            2140
# 4                 5                  Staff             1118            1035
# 5                 5                  Staff             2635            4075
# 6                 5                  Staff              774             218
# 7                 5                  Staff              508             330
# 8                 5                  Staff              178              27
# 9                 5                  Staff              110              41
#
#         Age Range Home Library Code Home Library Definition  \
# 0             NaN                b2                 Bayview
# ...
