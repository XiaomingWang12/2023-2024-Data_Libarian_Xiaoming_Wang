# %%
import pandas as pd
df = pd.read_csv("data/Library_Usage.csv")
df['Age Range'].value_counts()
# Out:
# /tmp/ipykernel_3283/1485194535.py:2: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("data/Library_Usage.csv")
# Age Range
# 25 to 34 years       92669
# 35 to 44 years       81719
# 10 to 19 years       66857
# 45 to 54 years       48319
# 0 to 9 years         32692
# 65 to 74 years       31714
# 20 to 24 years       25381
# 75 years and over    19297
# 55 to 59 years       19076
# 60 to 64 years       17654
# Name: count, dtype: int64

# %%
df['Age Range'].value_counts(normalize=True)
# Out:
# Age Range
# 25 to 34 years       0.212847
# 35 to 44 years       0.187697
# 10 to 19 years       0.153561
# 45 to 54 years       0.110982
# 0 to 9 years         0.075089
# 65 to 74 years       0.072842
# 20 to 24 years       0.058296
# 75 years and over    0.044322
# 55 to 59 years       0.043815
# 60 to 64 years       0.040549
# Name: proportion, dtype: float64

# %%
age_mode = df['Age Range'].mode()
age_mode[0]
# Out:
# '25 to 34 years'

# %%
df['Year Patron Registered'].value_counts()
# Out:
# Year Patron Registered
# 2022    52173
# 2019    44290
# 2003    41034
# 2021    32634
# 2020    32010
# 2017    29320
# 2018    28622
# 2023    26286
# 2016    21719
# 2015    20157
# 2014    15965
# 2013    13330
# 2012    12681
# 2011    12368
# 2009    11391
# 2010    11247
# 2008    10102
# 2007     6484
# 2006     5254
# 2005     4760
# 2004     4463
# Name: count, dtype: int64

# %%
df['Year Patron Registered'].value_counts(normalize=True)
# Out:
# Year Patron Registered
# 2022    0.119583
# 2019    0.101515
# 2003    0.094052
# 2021    0.074799
# 2020    0.073369
# 2017    0.067203
# 2018    0.065603
# 2023    0.060249
# 2016    0.049781
# 2015    0.046201
# 2014    0.036593
# 2013    0.030553
# 2012    0.029066
# 2011    0.028348
# 2009    0.026109
# 2010    0.025779
# 2008    0.023154
# 2007    0.014862
# 2006    0.012042
# 2005    0.010910
# 2004    0.010229
# Name: proportion, dtype: float64

# %%
Year_Patron_Registered_mode = df['Year Patron Registered'].mode()
Year_Patron_Registered_mode[0]
# Out:
# 2022

# %%
df[df['Age Range'].isna()]
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      5                  Staff               53
# 1                      5                  Staff              480
# 3                      5                  Staff             3934
# 4                      5                  Staff             1118
# 8                      5                  Staff              178
# ...                  ...                    ...              ...
# 436185                 5                  Staff             3883
# 436196                16    Digital Access Card              270
# 436211                 5                  Staff             2933
# 436225                 5                  Staff              664
# 436270                 5                  Staff                9
#
#         Total Renewals Age Range Home Library Code Home Library Definition  \
# 0                   15       NaN                b2                 Bayview
# 1                  378       NaN                e9               Excelsior
# 3                 2140       NaN                o2              Ocean View
# 4                 1035       NaN                o7                  Ortega
# 8                   27       NaN                 x                    Main
# ...                ...       ...               ...                     ...
# 436185            2906       NaN                 x                    Main
# 436196             430       NaN                 x                    Main
# 436211            3322       NaN                 x                    Main
# 436225             510       NaN                 x                    Main
# 436270               5       NaN                 x                    Main
#
#        Circulation Active Month  Circulation Active Year  \
# 0                           Mar                   2023.0
# 1                           Jun                   2023.0
# 3                           Jul                   2023.0
# 4                           Jul                   2023.0
# 8                           Apr                   2020.0
# ...                         ...                      ...
# 436185                      Jul                   2023.0
# 436196                      Jun                   2023.0
# 436211                      Jul                   2023.0
# 436225                      Jul                   2023.0
# 436270                      Feb                   2023.0
#
#        Notice Preference Code Notice Preference Definition  \
# 0                           z                        Email
# 1                           z                        Email
# 3                           z                        Email
# 4                           z                        Email
# 8                           z                        Email
# ...                       ...                          ...
# 436185                      z                        Email
# 436196                      z                        Email
# 436211                      z                        Email
# 436225                      z                        Email
# 436270                    NaN                          NaN
#
#         Provided Email Address  Year Patron Registered  \
# 0                         True                    2003
# 1                         True                    2003
# 3                         True                    2003
# 4                         True                    2003
# 8                         True                    2003
# ...                        ...                     ...
# 436185                    True                    2003
# 436196                    True                    2017
# 436211                    True                    2003
# 436225                    True                    2003
# 436270                   False                    2020
#
#        Within San Francisco County
# 0                            False
# 1                            False
# 3                            False
# 4                            False
# 8                            False
# ...                            ...
# 436185                         NaN
# 436196                         NaN
# 436211                         NaN
# 436225                         NaN
# 436270                         NaN
#
# [912 rows x 14 columns]

# %%
df.isna().sum()
# Out:
# Patron Type Code                    0
# Patron Type Definition              0
# Total Checkouts                     0
# Total Renewals                      0
# Age Range                         912
# Home Library Code                   2
# Home Library Definition            30
# Circulation Active Month        39513
# Circulation Active Year         39513
# Notice Preference Code          42989
# Notice Preference Definition    42989
# Provided Email Address              0
# Year Patron Registered              0
# Within San Francisco County      1207
# dtype: int64

# %%
df['Age Range'].fillna("25 to 34 years")
# Out:
# 0            25 to 34 years
# 1            25 to 34 years
# 2            45 to 54 years
# 3            25 to 34 years
# 4            25 to 34 years
#                 ...
# 436285       35 to 44 years
# 436286       10 to 19 years
# 436287       60 to 64 years
# 436288       35 to 44 years
# 436289    75 years and over
# Name: Age Range, Length: 436290, dtype: object

# %%
df['Total Checkouts'].mean()
# Out:
# 160.29484287973597

# %%
df['Total Checkouts'].median()
# Out:
# 7.0

# %%
df['Total Checkouts'].quantile(q=[0.25, 0.5, 0.75])
# Out:
# 0.25     0.0
# 0.50     7.0
# 0.75    78.0
# Name: Total Checkouts, dtype: float64

# %%
alpha = 0.005
df['Total Checkouts'].quantile([alpha, 1-alpha])
# Out:
# 0.005       0.000
# 0.995    3321.555
# Name: Total Checkouts, dtype: float64

# %%
alpha = 0.015
df['Total Checkouts'].quantile([alpha, 1-alpha])
# Out:
# 0.015       0.0
# 0.985    1965.0
# Name: Total Checkouts, dtype: float64

# %%
import numpy as np
df[(df["Total Checkouts"] > np.percentile(df["Total Checkouts"],1.5)) & (df["Total Checkouts"] < np.percentile(df["Total Checkouts"],98.5))]
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      5                  Staff               53
# 1                      5                  Staff              480
# 2                      5                  Staff               70
# 4                      5                  Staff             1118
# 6                      5                  Staff              774
# ...                  ...                    ...              ...
# 436285                 0                  Adult                2
# 436286                 2                   Teen                3
# 436287                 0                  Adult                6
# 436288                15           Teacher Card                4
# 436289                55          Retired Staff              309
#
#         Total Renewals          Age Range Home Library Code  \
# 0                   15                NaN                b2
# 1                  378                NaN                e9
# 2                   33     45 to 54 years                n4
# 4                 1035                NaN                o7
# 6                  218     55 to 59 years                 x
# ...                ...                ...               ...
# 436285               6     35 to 44 years               yjj
# 436286               0     10 to 19 years               yjj
# 436287               0     60 to 64 years               ylw
# 436288               0     35 to 44 years               ylw
# 436289             101  75 years and over               ylw
#
#        Home Library Definition Circulation Active Month  \
# 0                      Bayview                      Mar
# 1                    Excelsior                      Jun
# 2                   Noe Valley                      Jan
# 4                       Ortega                      Jul
# 6                         Main                      Jul
# ...                        ...                      ...
# 436285              Bookmobile                      Oct
# 436286              Bookmobile                      Nov
# 436287              Bookmobile                      Mar
# 436288              Bookmobile                      Sep
# 436289              Bookmobile                      Jul
#
#         Circulation Active Year Notice Preference Code  \
# 0                        2023.0                      z
# 1                        2023.0                      z
# 2                        2023.0                      z
# 4                        2023.0                      z
# 6                        2023.0                      z
# ...                         ...                    ...
# 436285                   2022.0                      z
# 436286                   2015.0                      z
# 436287                   2022.0                      z
# 436288                   2020.0                      z
# 436289                   2023.0                      z
#
#        Notice Preference Definition  Provided Email Address  \
# 0                             Email                    True
# 1                             Email                    True
# 2                             Email                    True
# 4                             Email                    True
# 6                             Email                    True
# ...                             ...                     ...
# 436285                        Email                    True
# 436286                        Email                    True
# 436287                        Email                    True
# 436288                        Email                    True
# 436289                        Email                    True
#
#         Year Patron Registered Within San Francisco County
# 0                         2003                       False
# 1                         2003                       False
# 2                         2011                       False
# 4                         2003                       False
# 6                         2003                       False
# ...                        ...                         ...
# 436285                    2020                         NaN
# 436286                    2011                         NaN
# 436287                    2022                         NaN
# 436288                    2019                         NaN
# 436289                    2003                         NaN
#
# [288942 rows x 14 columns]
