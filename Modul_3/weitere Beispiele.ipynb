# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# matplot inline
sns.set()

df = pd.read_csv("data/Library_Usage.csv")

# %%
df.head(10)
# Out:
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 5                  Staff               53              15
# 1                 5                  Staff              480             378
# 2                 5                  Staff               70              33
# 3                 5                  Staff             3934            2140
# 4                 5                  Staff             1118            1035
# 5                 5                  Staff             2635            4075
# 6                 5                  Staff              774             218
# 7                 5                  Staff              508             330
# 8                 5                  Staff              178              27
# 9                 5                  Staff              110              41
#
#         Age Range Home Library Code Home Library Definition  \
# 0             NaN                b2                 Bayview
# 1             NaN                e9               Excelsior
# 2  45 to 54 years                n4              Noe Valley
# 3             NaN                o2              Ocean View
# 4             NaN                o7                  Ortega
# 5  45 to 54 years                w2             West Portal
# 6  55 to 59 years                 x                    Main
# 7  45 to 54 years                 x                    Main
# 8             NaN                 x                    Main
# 9  45 to 54 years                 x                    Main
#
#   Circulation Active Month  Circulation Active Year Notice Preference Code  \
# 0                      Mar                   2023.0                      z
# 1                      Jun                   2023.0                      z
# 2                      Jan                   2023.0                      z
# 3                      Jul                   2023.0                      z
# 4                      Jul                   2023.0                      z
# 5                      Jul                   2023.0                      z
# 6                      Jul                   2023.0                      z
# 7                      Jul                   2023.0                      z
# 8                      Apr                   2020.0                      z
# 9                      Mar                   2023.0                      z
#
#   Notice Preference Definition  Provided Email Address  \
# 0                        Email                    True
# 1                        Email                    True
# 2                        Email                    True
# 3                        Email                    True
# 4                        Email                    True
# 5                        Email                    True
# 6                        Email                    True
# 7                        Email                    True
# 8                        Email                    True
# 9                        Email                    True
#
#    Year Patron Registered Within San Francisco County
# 0                    2003                       False
# 1                    2003                       False
# 2                    2011                       False
# 3                    2003                       False
# 4                    2003                       False
# 5                    2003                       False
# 6                    2003                       False
# 7                    2005                       False
# 8                    2003                       False
# 9                    2016                       False

# %%
# univariate Häufigkeits- und Bivarate Kreuztabellen können mit Balkendiagrammen visualisiert werden:

# %%
sns.catplot(y="Year Patron Registered",
            data=df, kind="count", color="pink")
# Out:
# /home/xiaoming/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(y="Age Range", hue="Provided Email Address",
            data=df, kind="count")
# Out:
# /home/xiaoming/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x="Patron Type Definition",
            data=df, kind="count", 
            col="Year Patron Registered", col_wrap=3)
# Out:
# /home/xiaoming/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Metrische Variablen
#univariate Verteilungen werden mit Histogrammen oder Kernel-Dichte Schätzern visualisiert:

# %%
#Histogram
sns.distplot(df["Total Renewals"], kde=False)
# Out:
# /tmp/ipykernel_3326/2460595148.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Total Renewals"], kde=False)
# <Axes: xlabel='Total Renewals'>

# %%
#with density estimation
sns.distplot(df["Total Renewals"], kde=True)
# Out:
# /tmp/ipykernel_3326/1860956012.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Total Renewals"], kde=True)
# <Axes: xlabel='Total Renewals', ylabel='Density'>

# %%
#Kombination aus metrischen und norminalen/ordinalen Variablen
# Swarmplot
