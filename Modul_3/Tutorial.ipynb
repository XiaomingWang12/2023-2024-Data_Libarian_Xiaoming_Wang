# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline
sns.set()

#use sample to generate a random subsample
df = pd.read_csv("data/Library_Usage.csv").sample(n=1000)
# Out:
# /tmp/ipykernel_6484/559781735.py:9: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("data/Library_Usage.csv").sample(n=1000)

# %%
sns.relplot(x="Total Checkouts", y="Total Renewals", data=df)
# Out:
# /home/xiaoming/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x="Total Checkouts", y="Total Renewals", data=df,
           height=5, aspect=3)
# Out:
# /home/xiaoming/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
tutorial=sns.relplot(x="Total Checkouts", y="Total Renewals", data=df,
           height=5, aspect=3)
plt.savefig("data/tutorial.png", dpi=150)
# Out:
# /home/xiaoming/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
tutorial=sns.relplot(x="Total Checkouts", y="Total Renewals",
           hue="Provided Email Address", style="Within San Francisco County",
                     size="Year Patron Registered", data=df)
# Out:
# /home/xiaoming/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Plot-Gitter
sns.relplot(x="Total Checkouts", y="Total Renewals",
            size="Year Patron Registered",
            row="Provided Email Address", col="Within San Francisco County", data=df)
# Out:
# /home/xiaoming/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Farbpaletten
sns.relplot(x="Total Checkouts", y="Total Renewals",
            hue="Provided Email Address",
            col="Within San Francisco County",
            palette=sns.color_palette("Accent", 2),
            data=df)
# Out:
# /home/xiaoming/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
