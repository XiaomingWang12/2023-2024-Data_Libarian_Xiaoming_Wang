# %%
#Streudiagram (Circulation Active 2023)
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_theme()

# %%
df = pd.read_csv("../data/Library_Usage.csv")
# Out:
# /tmp/ipykernel_4444/2005138213.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/Library_Usage.csv")

# %%
CAY_2023 = df.loc[df["Circulation Active Year"] == 2023]

# %%
CAY_2004 = df.loc[df["Circulation Active Year"] == 2004]

# %%
CAY_2023
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      5                  Staff               53
# 1                      5                  Staff              480
# 2                      5                  Staff               70
# 3                      5                  Staff             3934
# 4                      5                  Staff             1118
# ...                  ...                    ...              ...
# 436278                 4                Welcome                0
# 436281                 1               Juvenile                1
# 436282                16    Digital Access Card                0
# 436284                 0                  Adult               69
# 436289                55          Retired Staff              309
#
#         Total Renewals          Age Range Home Library Code  \
# 0                   15                NaN                b2
# 1                  378                NaN                e9
# ...

# %%
sns.relplot(x='Total Checkouts', y='Total Renewals', data=CAY_2023)
# Out:
# /home/xiaoming/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x='Total Checkouts', y='Total Renewals', data=CAY_2023
           height=5, aspect=3)
# Out:
#   Cell In[38], line 2
#     height=5, aspect=3)
#     ^
# SyntaxError: invalid syntax

# %%
###Kreuztabelle (Patron Type Definition & Age Range)
import pandas as pd

df = pd.read_csv(
    "../data/Library_Usage.csv",
)
pd.crosstab(
    df['Patron Type Definition'],
    df['Age Range'],
    margins=True
)
# Out:
# /tmp/ipykernel_4444/740275696.py:4: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
# Age Range               0 to 9 years  10 to 19 years  20 to 24 years  \
# Patron Type Definition
# Adult                             39            5437           23842
# At User Adult                      0               3               5
# At User Juvenile                   4               3               0
# At User Senior                     0               0               0
# At User Teen                       0               8               0
# At User Welcome                    0               1               1
# Business                           0               0               0
# Digital Access Card                3              60             269
# Juvenile                       32614           20649               1
# Library By Mail                    0               0               3
# ...
