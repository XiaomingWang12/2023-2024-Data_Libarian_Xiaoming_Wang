# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
x = range(1, 10)

# %%
# make a simple scatter plot of the data
plt.plot(x, x, c="black", linestyle='-', marker='o')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# setup the seaborn library
sns.set()

# %%
x = range(1, 10)
plt.plot(x, x)
