# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set()

# %%
dat = pd.DataFrame()
vals = [0.8, 1, 4]
for alpha in vals:
    for beta in vals:
        x = {
            'x': np.random.beta(alpha, beta, size = 100000),
            'alpha': alpha,
            'beta': beta
        }
        x['mean'] = np.mean(x['x'])
        x['median'] = np.median(x['x'])
        dat = pd.concat([dat,pd.DataFrame(x)])

def vertical_line(x, **kwargs):
    plt.axvline(x[1], **kwargs)

g = sns.FacetGrid(dat, col="alpha", row="beta", sharey=False, height=4)
g = g.map(vertical_line, "mean", c='#e35349', label='Mean')
g = g.map(vertical_line, "median", c='#e35349', label='Median', linestyle="--")
g = g.map(sns.histplot, 'x', kde=False).add_legend()
g.savefig("./distributions.png", dpi=150)
g
# Out:
# /home/xiaoming/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /home/xiaoming/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /home/xiaoming/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline
sns.set()

df = pd.read_csv("data/Library_Usage.csv")
sns.distplot(df['Total Checkouts'], kde=False)
# Out:
# /tmp/ipykernel_3975/226110736.py:6: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("data/Library_Usage.csv")
# /tmp/ipykernel_3975/226110736.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Total Checkouts'], kde=False)
# <Axes: xlabel='Total Checkouts'>

# %%
df["Total Checkouts Sqrt"] = df['Total Checkouts']**(0.5)

# %%
df.head(10)
# Out:
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 5                  Staff               53              15
# 1                 5                  Staff              480             378
# 2                 5                  Staff               70              33
# 3                 5                  Staff             3934            2140
# 4                 5                  Staff             1118            1035
# 5                 5                  Staff             2635            4075
# 6                 5                  Staff              774             218
# 7                 5                  Staff              508             330
# 8                 5                  Staff              178              27
# 9                 5                  Staff              110              41
#
#         Age Range Home Library Code Home Library Definition  \
# 0             NaN                b2                 Bayview
# 1             NaN                e9               Excelsior
# 2  45 to 54 years                n4              Noe Valley
# 3             NaN                o2              Ocean View
# 4             NaN                o7                  Ortega
# 5  45 to 54 years                w2             West Portal
# 6  55 to 59 years                 x                    Main
# 7  45 to 54 years                 x                    Main
# 8             NaN                 x                    Main
# 9  45 to 54 years                 x                    Main
#
#   Circulation Active Month  Circulation Active Year Notice Preference Code  \
# 0                      Mar                   2023.0                      z
# 1                      Jun                   2023.0                      z
# 2                      Jan                   2023.0                      z
# 3                      Jul                   2023.0                      z
# 4                      Jul                   2023.0                      z
# 5                      Jul                   2023.0                      z
# 6                      Jul                   2023.0                      z
# 7                      Jul                   2023.0                      z
# 8                      Apr                   2020.0                      z
# 9                      Mar                   2023.0                      z
#
#   Notice Preference Definition  Provided Email Address  \
# 0                        Email                    True
# 1                        Email                    True
# 2                        Email                    True
# 3                        Email                    True
# 4                        Email                    True
# 5                        Email                    True
# 6                        Email                    True
# 7                        Email                    True
# 8                        Email                    True
# 9                        Email                    True
#
#    Year Patron Registered Within San Francisco County  Total Checkouts Sqrt
# 0                    2003                       False              7.280110
# 1                    2003                       False             21.908902
# 2                    2011                       False              8.366600
# 3                    2003                       False             62.721607
# 4                    2003                       False             33.436507
# 5                    2003                       False             51.332251
# 6                    2003                       False             27.820855
# 7                    2005                       False             22.538855
# 8                    2003                       False             13.341664
# 9                    2016                       False             10.488088

# %%
sns.distplot(df['Total Checkouts Sqrt'], kde=False)
# Out:
# /tmp/ipykernel_3975/4272173287.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Total Checkouts Sqrt'], kde=False)
# <Axes: xlabel='Total Checkouts Sqrt'>

# %%
###Boxplot-Verteilung der Ausleihen nach Jahr der Registrierung

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

import pandas as pd

df = pd.read_csv("data/Library_Usage.csv")
df = df[df['Total Checkouts'] < 816]
plt.figure(figsize=(16, 6))
plt = sns.boxplot(y='Total Checkouts', x='Year Patron Registered', data=df, fliersize=0.5, whis=1.5)
plt.get_figure().savefig("boxplots.png")
# Out:
# /tmp/ipykernel_3975/4156804284.py:7: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("data/Library_Usage.csv")

# %%
import pandas as pd
df = pd.read_csv(
    "data/Library_Usage.csv",
    na_values="none"
)
pd.crosstab(
    df['Provided Email Address'],
    df['Notice Preference Definition'],
    margins=True
)
# Out:
# /tmp/ipykernel_3975/1603364262.py:2: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
# Notice Preference Definition   Email     All
# Provided Email Address
# True                          393301  393301
# All                           393301  393301

# %%
pd.crosstab(
    df['Provided Email Address'],
    df['Notice Preference Definition'],
    margins=True, normalize=1
)
# Out:
# Notice Preference Definition  Email  All
# Provided Email Address
# True                            1.0  1.0

# %%
pd.crosstab(
    df['Provided Email Address'],
    df['Notice Preference Definition'],
    margins=True, normalize=0
)
# Out:
# Notice Preference Definition  Email
# Provided Email Address
# True                            1.0
# All                             1.0
